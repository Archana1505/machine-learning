# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
sample=pd.read_csv("E:\Students.csv")
print(sample)
x=sample.iloc[:,:-1]
y=sample.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=123)
std_reg=LinearRegression()
std_reg.fit(x_train,y_train)
y_p=std_reg.predict(x_test)
print("x_test data")
print(x_test)
print("predicted values of y",y_p)
plt.scatter(x_test,y_test)
plt.plot(x_test,y_p)
plt.show()
# Out:
#     Hours  Marks
# 0       0     34
# 1       1     36
# 2       1     33
# 3       1     39
# 4       1     42
# 5       2     45
# 6       2     38
# 7       3     45
# 8       3     53
# 9       3     46
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88
# 20      7     61
# 21      7     74
# 22      8     71
# 23      8     89
# 24      9     82
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79
# x_test data
#     Hours
# 7       3
# 29     11
# 5       2
# 26      9
# 8       3
# 27     10
# 12      4
# 21      7
# 11      4
# predicted values of y [49.88910506 92.75486381 44.53088521 82.03842412 49.88910506 87.39664397
#  55.2473249  71.32198444 55.2473249 ]
